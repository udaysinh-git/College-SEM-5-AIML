# %% [markdown]
# <a href="https://colab.research.google.com/github/udaysinh-git/College-SEM-5-AIML/blob/main/qcai_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install qiskit-aer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 65.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 101.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 106.5 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram
import matplotlib.pyplot as plt
from IPython.display import display

# %%
qc0 = QuantumCircuit(1)
qc0.h(0)

# %%
state0 = Statevector.from_instruction(qc0)
print("Statevector after applying H on |0>\n",state0)
# Out:
# Statevector after applying H on |0>
#  Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
fig1 = plot_bloch_multivector(state0)
display(fig1)

# %%
qc1 = QuantumCircuit(1)
qc1.x(0)
qc1.h(0)

# %%
state1 = Statevector.from_instruction(qc1)
print("Statevector after applying H on |1>\n",state1)
# Out:
# Statevector after applying H on |1>
#  Statevector([ 0.70710678+0.j, -0.70710678+0.j],
#             dims=(2,))

# %%
fig2 = plot_bloch_multivector(state1)
display(fig2)

# %%
qc_measure = QuantumCircuit(1,1)
qc_measure.h(0)
qc_measure.measure(0,0)

# %%
qc_measure.draw()
# Out:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0

# %%
simulator = AerSimulator()
compiled_circuit = transpile(qc_measure, simulator)
job = simulator.run(compiled_circuit, shots=10000).result()
counts = job.get_counts()

# %%
fig3 = plot_histogram(counts)
display(fig3)
